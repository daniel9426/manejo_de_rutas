# %% [markdown]
# # Paths management Platzi

# %% [markdown]
# ## Different python paths management systems

# %% [markdown]
# ### OS

# %%
import os

# %%
CURRENT_DIR = os.getcwd() # Retrieve current directory

print(type(CURRENT_DIR))

print(os.path.abspath(os.path.join(CURRENT_DIR, os.pardir))) # parent directory...
DATA_DIR = os.path.join(CURRENT_DIR, os.pardir, "data/") # os.pardir: ..

print(DATA_DIR)
print(os.path.exists(DATA_DIR))
print(os.path.isdir(DATA_DIR))
# Out:
# <class 'str'>
# /home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas
# /home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/notebooks/../data/
# True
# True

# %%
[os.path.join(DATA_DIR, item) for item in os.listdir(DATA_DIR)]
# Out:
# ['/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/notebooks/../data/raw',
#  '/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/notebooks/../data/processed']

# %%
os.mkdir(os.path.join(DATA_DIR, "external_os"))

# %%
os.makedirs(os.path.join(DATA_DIR, "external_os", "os", "nested"))

# %% [markdown]
# ### Pathlib

# %%
import pathlib

# %%
CURRENT_DIR = pathlib.Path(".").resolve()
print(type(CURRENT_DIR))

DATA_DIR = CURRENT_DIR.parent.joinpath("data") # CURRENT_DIR.parent / "data"
print(DATA_DIR)
print(DATA_DIR.exists())
print(DATA_DIR.is_dir())
# Out:
# <class 'pathlib.PosixPath'>
# /home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data
# True
# True

# %%
list(DATA_DIR.glob("*"))
# Out:
# [PosixPath('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data/raw'),
#  PosixPath('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data/external_os'),
#  PosixPath('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data/processed')]

# %%
DATA_DIR.joinpath("external_pathlib", "pathlib", "nested").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### fs

# %%
import fs

# %%
CURRENT_DIR = fs.open_fs(".")
print(CURRENT_DIR.exists("."))
CURRENT_DIR.exists("..")
# Out:
# True
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/path.py:85, in normpath(path)
#      84     if component == "..":
# ---> 85         components.pop()
#      86 else:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# IllegalBackReference                      Traceback (most recent call last)
# Cell In[11], line 3
#       1 CURRENT_DIR = fs.open_fs(".")
#       2 print(CURRENT_DIR.exists("."))
# ----> 3 CURRENT_DIR.exists("..")
#
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/base.py:523, in FS.exists(self, path)
#     513 """Check if a path maps to a resource.
#     514
#     515 Arguments:
#    (...)
#     520
#     521 """
#     522 try:
# --> 523     self.getinfo(path)
#     524 except errors.ResourceNotFound:
#     525     return False
#
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/osfs.py:284, in OSFS.getinfo(self, path, namespaces)
#     282 self.check()
#     283 namespaces = namespaces or ()
# --> 284 _path = self.validatepath(path)
#     285 sys_path = self.getsyspath(_path)
#     286 _lstat = None
#
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/osfs.py:687, in OSFS.validatepath(self, path)
#     681 except UnicodeEncodeError as error:
#     682     raise errors.InvalidCharsInPath(
#     683         path,
#     684         msg="path '{path}' could not be encoded for the filesystem (check LANG"
#     685         " env var); {error}".format(path=path, error=error),
#     686     )
# --> 687 return super(OSFS, self).validatepath(path)
#
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/base.py:1590, in FS.validatepath(self, path)
#    1588             msg = _msg.format(max_chars=max_sys_path_length)
#    1589             raise errors.InvalidPath(path, msg=msg)
# -> 1590 path = abspath(normpath(path))
#    1591 return path
#
# File ~/anaconda3/envs/manejo_de_rutas/lib/python3.10/site-packages/fs/path.py:90, in normpath(path)
#      87             components.append(component)
#      88 except IndexError:
#      89     # FIXME (@althonos): should be raised from the IndexError
# ---> 90     raise IllegalBackReference(path)
#      91 return prefix + "/".join(components)
#
# IllegalBackReference: path '..' contains back-references outside of filesystem

# %%
DATA_DIR = fs.open_fs("../data")
print(DATA_DIR.exists(""))

for path in DATA_DIR.walk.files(): # walk.dirs
    print(path)

    with DATA_DIR.open(path) as data_files:
        print(data_files.readline())
# Out:
# True
# /raw/.gitkeep
#
# /processed/.gitkeep

# %%
DATA_DIR.makedir("external_fs", recreate=True)
# Out:
# SubFS(OSFS('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data'), '/external_fs')

# %%
sub_data_dir = DATA_DIR.makedirs("external_fs/fs/nested", recreate=True)

# %%
sub_data_dir.makedir("test")
# Out:
# SubFS(OSFS('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data'), '/external_fs/fs/nested/test')

# %% [markdown]
# ## Adding root to the project

# %%
import pyprojroot

# %%
pyprojroot.here().joinpath("data", "raw")
# Out:
# PosixPath('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/data/raw')

# %%
import pyhere

# %%
pyhere.here("data", "raw")
# Out:
# PosixPath('/home/daniel9426/cookiecutter_manejo_de_rutas/manejo_de_rutas/notebooks/../data/raw')

# %% [markdown]
# ## Crete custom shortcuts

# %%
# Nested function.
def make_dir_function(dir_name):
    def dir_function(*args):

        if isinstance(dir_name, str):
            return pyprojroot.here().joinpath(dir_name, *args)
        else:
            return pyprojroot.here().joinpath(*dir_name, *args)

    return dir_function

# Nested lambda.
make_dir_function_lambda = lambda dir_name: lambda *args: pyprojroot.here().joinpath(dir_name, *args)

# %%
data_dir = make_dir_function("data")
data_dir("external", "os", "do")
# Out:
# PosixPath('/Users/jvelezmagic/Documents/Github/personal_projects/curso-entorno-avanzado-ds/data/external/os/do')

# %%
figures_dir = make_dir_function_lambda("figures")
figures_dir("amazing", "plots", "here")
# Out:
# PosixPath('/Users/jvelezmagic/Documents/Github/personal_projects/curso-entorno-avanzado-ds/figures/amazing/plots/here')
